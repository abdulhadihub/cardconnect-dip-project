# %% [markdown]
# # CardConnect
# ## Group Members
# ### SP21-BCS-045-Abdul Hadi
# ### SP21-BCS-051-Ali Raza
# ### SP21-BCS-065-Najam Ul Hassan
#
# ## Introduction
# CardConnect is a project that aims to revolutionize the way business card data is processed and organized. In today's fast-paced world, manually entering contact information from business cards into digital systems is time-consuming and error-prone. CardConnect addresses this issue by leveraging machine learning technology to automatically scan, extract, and categorize business card information, such as names, phone numbers, and email addresses. This streamlines this essential task and contributes to the advancement of digital image processing and data automation.
#
# ### Step 1 - User will take image of target business card
#
# ### Step 2 - Server running our program will return extracted information
#
# ### Step 3 - Contact will be added to app
#
# ### Step 4 - Use extracted information to generate report

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from extract_text_module import ImageProcessor
from text_to_json_module import TextExtractor


screen1 = cv2.imread('presentation-assets/screen1.jpg')
screen2 = cv2.imread('presentation-assets/screen2.jpg')
screen3 = cv2.imread('presentation-assets/screen3.jpg')


plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(screen1)
plt.show()
plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(screen2)
plt.show()
plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(screen3)
plt.show()

# %%
image_path = 'image_downloads/image_6.jpg'
# image_path = 'image_downloads/image_11.jpg'
# image_path = 'image_downloads/image_22.jpg'
# image_path = 'image_downloads/image_27.jpg'
# image_path = 'image_downloads/image_31.jpg'
input_image = cv2.imread(image_path)
image_processor = ImageProcessor()
# detected_entities = image_processor.process_image(input_image, False, True, 50, 5, 5000, 1000000)
# detected_entities = image_processor.process_image(input_image, False, True, 100, 50, 100000, 10000000000)
detected_entities = image_processor.process_image(input_image, False, True, 100, 50, 100000, 10000000000)
text_extractor = TextExtractor()
extracted_data = text_extractor.extract_info_from_list(detected_entities)
print(extracted_data)
# Out:
# {
#     "phone": "650",
#     "email": "ulate@ee.stanford.edu"
# }
