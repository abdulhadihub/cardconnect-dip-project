# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from extract_text_module import ImageProcessor
from text_to_json_module import TextExtractor

image_path = 'image_downloads/image_35.jpg'

# Create an ImageProcessor object
image_processor = ImageProcessor()
detected_entities = image_processor.process_image(image_path, deskew=True, showROI=True)
print(detected_entities)
# Out:
# [[159 213]
#  [  0   0]
#  [  0   0]
#  [  0   0]]
# [[159 213]
#  [673 237]
#  [  0   0]
#  [  0   0]]
# [[159 213]
#  [673 237]
#  [116 538]
#  [  0   0]]
# [[159 213]
#  [673 237]
#  [116 538]
#  [710 530]]
# btnaccess
# Beyond the Network Limited
# 20th Floor, East Exchange Towe
# 38 Leighton Road
# Causeway Bay, Hong Kong
# +91 22 5651 0827
# @ +91 225651 0826
# @ +91 98 2074 4226
# G igandhi@btnaccess.com
# @ wowbtnaccess.com
# Jimit Gandhi
# ‘APEMEA
# Beyond the Network Limited
# 20th Floor, East Exchange Tower
# 38 Leighton Road
# Causeway Bay, Hong Kong
# +91 22 5651 0827
# @ +91 225651 0826
# @ +91 98 2074 4226
# G igandhi@btnaccess.com
# @ wwwdbtnaccess.com
# ['@ +91 225651 0826', 'Beyond the Network Limited', '@ wwwdbtnaccess.com', '‘APEMEA', 'btnaccess', 'G igandhi@btnaccess.com', '+91 22 5651 0827', '20th Floor, East Exchange Towe', '20th Floor, East Exchange Tower', 'Jimit Gandhi', 'Causeway Bay, Hong Kong', '38 Leighton Road', '@ wowbtnaccess.com', '@ +91 98 2074 4226']

# %%
text_extractor = TextExtractor()
extracted_data = text_extractor.extract_info_from_list(detected_entities)
print(extracted_data)
# Out:
# {
#     "entities": [
#         {
#             "Entity": "@ +91 225651 0826",
#             "Phone": "+91 225651 0826",
#             "Email": null
#         },
#         {
#             "Entity": "Beyond the Network Limited",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "@ wwwdbtnaccess.com",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "\u2018APEMEA",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "btnaccess",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "G igandhi@btnaccess.com",
#             "Phone": null,
#             "Email": "igandhi@btnaccess.com"
#         },
#         {
#             "Entity": "+91 22 5651 0827",
#             "Phone": "+91 22 5651 0827",
#             "Email": null
#         },
#         {
#             "Entity": "20th Floor, East Exchange Towe",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "20th Floor, East Exchange Tower",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "Jimit Gandhi",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "Causeway Bay, Hong Kong",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "38 Leighton Road",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "@ wowbtnaccess.com",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "@ +91 98 2074 4226",
#             "Phone": "+91 98 2074 4226",
#             "Email": null
#         }
#     ]
# }
