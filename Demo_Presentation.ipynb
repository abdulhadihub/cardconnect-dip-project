# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from extract_text_module import ImageProcessor
from text_to_json_module import TextExtractor

image_path = 'image_downloads/image_540.jpg'

# Create an ImageProcessor object
image_processor = ImageProcessor()
detected_entities = image_processor.process_image(image_path, deskew=True, showROI=True)
print(detected_entities)
# Out:
# [[11  9]
#  [ 0  0]
#  [ 0  0]
#  [ 0  0]]
# [[ 11   9]
#  [791  14]
#  [  0   0]
#  [  0   0]]
# [[ 11   9]
#  [791  14]
#  [  8 460]
#  [  0   0]]
# [[ 11   9]
#  [791  14]
#  [  8 460]
#  [794 473]]
# cell# 0301-2006891
# MEHR TALHA NOO
# hévecas Hah Camel
# Advocate High Court—_J
# E-Mail.MehrTalhaNoor@gmail.com
# OFFICE: NEW JUDICIAL COMPLEX HASILPUR
# DISTRICT.COURTS BAHAWALPUR
# ['Advocate High Court—_J', 'hévecas Hah Camel', 'E-Mail.MehrTalhaNoor@gmail.com', 'MEHR TALHA NOO', 'cell# 0301-2006891', 'DISTRICT.COURTS BAHAWALPUR', 'OFFICE: NEW JUDICIAL COMPLEX HASILPUR']

# %%
text_extractor = TextExtractor()
extracted_data = text_extractor.extract_info_from_list(detected_entities)
print(extracted_data)
# Out:
# {
#     "entities": [
#         {
#             "Entity": "Advocate High Court\u2014_J",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "h\u00e9vecas Hah Camel",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "E-Mail.MehrTalhaNoor@gmail.com",
#             "Phone": null,
#             "Email": "E-Mail.MehrTalhaNoor@gmail.com"
#         },
#         {
#             "Entity": "MEHR TALHA NOO",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "cell# 0301-2006891",
#             "Phone": " 0301-2006891",
#             "Email": null
#         },
#         {
#             "Entity": "DISTRICT.COURTS BAHAWALPUR",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "OFFICE: NEW JUDICIAL COMPLEX HASILPUR",
#             "Phone": null,
#             "Email": null
#         }
#     ]
# }
