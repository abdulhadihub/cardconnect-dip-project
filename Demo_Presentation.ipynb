# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from extract_text_module import ImageProcessor
from text_to_json_module import TextExtractor

image_path = 'image_downloads/image_35.jpg'

# Create an ImageProcessor object
image_processor = ImageProcessor()
detected_entities = image_processor.process_image(image_path, deskew=True, showROI=True)
print(detected_entities)

# %%
text_extractor = TextExtractor()
extracted_data = text_extractor.extract_info_from_list(detected_entities)
print(extracted_data)
# Out:
# {
#     "entities": [
#         {
#             "Entity": "2 btnaccess 3",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "f G igandhi@btnaccess.com \u2018",
#             "Phone": null,
#             "Email": "igandhi@btnaccess.com"
#         },
#         {
#             "Entity": "7 2. 44 Wa \u2014 ?",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "Ka / a+ \u201cVARA QV",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "@ +91 98 2074 4226 %",
#             "Phone": "+91 98 2074 4226",
#             "Email": null
#         },
#         {
#             "Entity": "= r",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "~ \u2019",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "_t ;",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "s @ +91 22 5651 0827 .",
#             "Phone": "+91 22 5651 0827",
#             "Email": null
#         },
#         {
#             "Entity": "0k 20th Floor, East Exchange Tower PuDEeanahy . eg",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "a UTS weneeees \u00ab oe",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": ": \u00a9 www.btnaccess.com RECOM eee",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "\u00a9 m-) -, ma ooo \u00e9",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "B 38 Leighton Road",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "-/ eB < ae",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "/ : 1 PRMQACCT",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "- @ +91 225651 0826",
#             "Phone": "+91 225651 0826",
#             "Email": null
#         },
#         {
#             "Entity": "Causeway Bay, Hong Kong",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "\u2014 - /fF a : w=",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "\u2018 Beyond the Network Limited imi i \u2018 2",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "oe a \u2122*.",
#             "Phone": null,
#             "Email": null
#         },
#         {
#             "Entity": "\u00a3 ; Se Ws",
#             "Phone": null,
#             "Email": null
#         }
#     ]
# }
